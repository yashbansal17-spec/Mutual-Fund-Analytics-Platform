# %% [markdown]
# # 01 Data Ingestion

# %% [markdown]
# ## Required Sections
# - Load all 10 datasets
# - Print shape, dtypes, and head
# - Validate AMFI codes
# - Fetch live NAV using scripts/live_nav_fetch.py

# %%
from pathlib import Path
import pandas as pd
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
PROCESSED = PROJECT_ROOT / 'data' / 'processed'
pd.read_csv(PROCESSED / 'fund_scorecard.csv').head()
