# %% [markdown]
# # 04 Performance Analytics

# %% [markdown]
# ## Required Sections
# - Daily returns
# - CAGR with trading-day annualisation
# - Sharpe and Sortino
# - Alpha/Beta vs benchmark
# - Max drawdown
# - Composite scorecard

# %%
from pathlib import Path
import pandas as pd
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
PROCESSED = PROJECT_ROOT / 'data' / 'processed'
pd.read_csv(PROCESSED / 'fund_scorecard.csv').head()
