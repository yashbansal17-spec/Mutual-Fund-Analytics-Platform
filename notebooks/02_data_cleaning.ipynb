# %% [markdown]
# # 02 Data Cleaning

# %% [markdown]
# ## Required Sections
# - Clean date fields
# - Forward-fill NAV weekends and holidays
# - Load SQLite schema
# - Review data dictionary

# %%
from pathlib import Path
import pandas as pd
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
PROCESSED = PROJECT_ROOT / 'data' / 'processed'
pd.read_csv(PROCESSED / 'fund_scorecard.csv').head()
